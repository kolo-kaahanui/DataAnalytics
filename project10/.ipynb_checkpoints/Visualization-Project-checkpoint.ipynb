# %% [markdown]
# # Visualization Project
#
# The goal of this project is to showcase my data visualization skills.
#
# ## The Data
#
# This dataset contains meta-data (including price) of roughly 54,000 diamonds.
#
# #### Content
#
# * price price in US dollars (\$326--\$18,823)
#
# * carat weight of the diamond (0.2--5.01)
#
# * cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# * color diamond colour, from J (worst) to D (best)
#
# * clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# * x length in mm (0--10.74)
#
# * y width in mm (0--58.9)
#
# * z depth in mm (0--31.8)
#
# * depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# * table width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
diamonds = pd.read_csv('./diamonds.csv')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# #### A scatterplot of price versus carat

# %%
sns.scatterplot(data=diamonds, x='carat', y="price")
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# #### Changing the alpha  and edgecolor parameters to deal with the overlapping and white edgemarker issue.

# %%
sns.scatterplot(data=diamonds, x='carat', y="price", alpha=.2, edgecolor='lightblue')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# #### Plot Resize

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=diamonds, x='carat', y="price", alpha=.2, edgecolor='lightblue')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# #### A histogram of the price column

# %%
plt.figure(figsize=(10,8))
sns.distplot(diamonds['price'],kde=None)
# Out:
# c:\users\kolok\anaconda3\envs\py38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# #### A count plot of the instances per cut type

# %%
sns.countplot(diamonds['cut'])
# Out:
# c:\users\kolok\anaconda3\envs\py38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %% [markdown]
# #### The price distribution per cut type

# %%
sns.boxplot(data=diamonds,y="price", x="cut")
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# #### Changing the cut type ordering

# %%
sns.boxplot(data=diamonds,y="price", x="cut", order=["Fair","Ideal","Good", "Very Good", "Premium"], palette="deep")
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# #### Changing the color

# %%
sns.boxplot(data=diamonds,y="price", x="cut", order=["Fair","Ideal","Good", "Very Good", "Premium"], palette="cool" )
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# #### And why not end with a heatmap?

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=diamonds.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Conclusion

# %% [markdown]
# This is close to the tenth time doing such visualization so to speak more to my understanding, performing a heatmap on the correlation columns is a good way to visualize correlation. Knowing the correlated features is valuable when trying to infer predictions using new data. Sometimes we are interested in some specific feature, which is where some kind of distribution graph is interesting (often a histogram). In a course called Statistics for Business Analytics and Data Science, I learned that we often want to see a normal distribution in these individual features. If we want to see a correlation between two different variables (say between a feature and a 'target' column), we can use a scatter plot. This should help an analyst make sense of say, the calculated correlation. I also use boxplots in this Excercise. The box plots are another way to look at the distribution of some 'label' with respect to another variable. More so, boxplots are helpful in comparing multiple two variable distributions. This was a good option for when I compared the different cut ratings of diamonds to the price variable. This project turned out to be a great opportunity to practice my visualization skills.
